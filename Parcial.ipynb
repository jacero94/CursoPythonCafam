# %% [markdown]
# <a href="https://colab.research.google.com/github/jacero94/CursoPythonCafam/blob/main/Parcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ¿Como podemos agrupar los estados?

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('/content/sample_data/crime_data.csv')

# %%
dataset
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
State = dataset.iloc[:, [0]].values
Homicidios = dataset.iloc[:, [1]].values
Asaltos = dataset.iloc[:, [2]].values
Poblacion_area_urbana = dataset.iloc[:, [3]].values
Violaciones = dataset.iloc[:, [4]].values

# %%
Violaciones
# Out:
# array([[21.2],
#        [44.5],
#        [31. ],
#        [19.5],
#        [40.6],
#        [38.7],
#        [11.1],
#        [15.8],
#        [31.9],
#        [25.8],
#        [20.2],
#        [14.2],
#        [24. ],
#        [21. ],
#        [11.3],
#        [18. ],
#        [16.3],
#        [22.2],
#        [ 7.8],
#        [27.8],
#        [16.3],
#        [35.1],
#        [14.9],
#        [17.1],
#        [28.2],
#        [16.4],
#        [16.5],
#        [46. ],
#        [ 9.5],
#        [18.8],
#        [32.1],
#        [26.1],
#        [16.1],
#        [ 7.3],
#        [21.4],
#        [20. ],
#        [29.3],
#        [14.9],
#        [ 8.3],
#        [22.5],
#        [12.8],
#        [26.9],
#        [25.5],
#        [22.9],
#        [11.2],
#        [20.7],
#        [26.2],
#        [ 9.3],
#        [10.8],
#        [15.6]])

# %%
X = dataset.iloc[:,[1,2,3,4]].values

# %%
X
# Out:
# array([[ 13.2, 236. ,  58. ,  21.2],
#        [ 10. , 263. ,  48. ,  44.5],
#        [  8.1, 294. ,  80. ,  31. ],
#        [  8.8, 190. ,  50. ,  19.5],
#        [  9. , 276. ,  91. ,  40.6],
#        [  7.9, 204. ,  78. ,  38.7],
#        [  3.3, 110. ,  77. ,  11.1],
#        [  5.9, 238. ,  72. ,  15.8],
#        [ 15.4, 335. ,  80. ,  31.9],
#        [ 17.4, 211. ,  60. ,  25.8],
#        [  5.3,  46. ,  83. ,  20.2],
#        [  2.6, 120. ,  54. ,  14.2],
#        [ 10.4, 249. ,  83. ,  24. ],
#        [  7.2, 113. ,  65. ,  21. ],
#        [  2.2,  56. ,  57. ,  11.3],
#        [  6. , 115. ,  66. ,  18. ],
#        [  9.7, 109. ,  52. ,  16.3],
#        [ 15.4, 249. ,  66. ,  22.2],
#        [  2.1,  83. ,  51. ,   7.8],
#        [ 11.3, 300. ,  67. ,  27.8],
#        [  4.4, 149. ,  85. ,  16.3],
#        [ 12.1, 255. ,  74. ,  35.1],
#        [  2.7,  72. ,  66. ,  14.9],
#        [ 16.1, 259. ,  44. ,  17.1],
#        [  9. , 178. ,  70. ,  28.2],
# ...

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
dataset['Cluster'] = y_kmeans

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.countplot(x='Cluster', data=dataset, palette='viridis')
plt.xlabel('Cluster')
plt.ylabel('Número de Estados')
plt.title('Número de Estados en Cada Cluster')
plt.show()
# Out:
# <ipython-input-67-ff2d0827632c>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Cluster', data=dataset, palette='viridis')

# %% [markdown]
# Se logra ver que el resultado del ejercicio son de 3 clusteres, en donde se clasifican con complejidad:
#
# * Cluster 0: Complejidad Baja.
# * Cluster 1: Complejidad Media.
# * Cluster 2: Complejidad Alta.

# %% [markdown]
# ¿Cuáles son los estados con necesidad de profesionales con mayor capacidad de atención
# al crimen?

# %%
from sklearn.preprocessing import StandardScaler
Y = dataset.iloc[:,[1,2,3,4]].values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
wcss1 = []
for j in range(1, 11):
    kmeans = KMeans(n_clusters = j, init = 'k-means++', random_state = 42)
    kmeans.fit(X_scaled)
    wcss1.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss1)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
kmeans = kmeans.fit_predict(X_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
dataset['Cluster'] = kmeans

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6))
sns.countplot(x='Cluster', data=dataset, palette='viridis')
plt.xlabel('Cluster')
plt.ylabel('Número de Estados')
plt.title('Número de Estados en Cada Cluster')
plt.show()
# Out:
# <ipython-input-71-ff2d0827632c>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Cluster', data=dataset, palette='viridis')

# %% [markdown]
# Se logra ver que el resultado del ejercicio son de 3 clusteres, en donde se clasifican con complejidad:
#
# Cluster 0: Complejidad Baja.
# Cluster 1: Complejidad Media.
# Cluster 2: Complejidad Alta.
#
# Recursos 300 policias capacitados cluster 2.
# Recursos 500 policias de a pie cluster 1.
# Recursos 150 cadetes cluster 0.
