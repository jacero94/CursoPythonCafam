# %% [markdown]
# <a href="https://colab.research.google.com/github/jacero94/CursoPythonCafam/blob/main/TallerLimpiezaPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![images.png](data:image/png;base64,...)
#
#
# **TALLER LIBRERIAS**
#
# CURSO DE PYTHON
#
# DIRECCION DE EDUCACIÓN CONTINUA
#
# FUNDACION UNIVERSITARIA CAFAM
#
# DOCENTE: NICOLAS MOJICA GOMEZ
#
# ESTUDIANTE: **FRANCISCO JAVIER ACERO TORRES**

# %%
import pandas as pd
excel = pd.read_excel("/content/sample_data/EjercicioLimpiezaPython.xlsm")

# %%
excel
# Out:
#            CEDULA  N° Cuentas  N° CDT  N° Tarjetas De Crédito  \
# 0    9.375240e+06          64       2                      12
# 1    1.023008e+09          93       6                      16
# 2    4.196091e+07          61       3                      10
# 3    1.010229e+09          63       2                      14
# 4    1.054920e+09          80       3                      15
# ..            ...         ...     ...                     ...
# 491  8.080704e+07          85       9                      12
# 492  8.005812e+07          74       1                       8
# 493  5.206726e+07          78       6                      12
# 494  1.088009e+09          99       6                      19
# 495           NaN       30842    1503                    4249
#
#      N° Debitos Automáticos  Plan Familia (Millones)  Consumo (Millones)  \
# 0                         1             6.150000e+06        8.500000e+07
# ...

# %%
excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 496 entries, 0 to 495
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CEDULA                      495 non-null    float64
#  1   N° Cuentas                  496 non-null    int64
#  2   N° CDT                      496 non-null    int64
#  3   N° Tarjetas De Crédito      496 non-null    int64
#  4   N° Debitos Automáticos      496 non-null    int64
#  5   Plan Familia (Millones)     496 non-null    float64
#  6   Consumo (Millones)          496 non-null    float64
#  7   Libranza (Millones)         496 non-null    float64
#  8   Compra Cartera (Millones)   496 non-null    int64
#  9   Vehículo (Millones)         496 non-null    int64
#  10  N°  Seguros Desempleo       496 non-null    int64
#  11  N° Seguros Fraude           496 non-null    int64
#  12  N° Seguros Accidentes Per.  496 non-null    int64
# ...

# %%
excel.describe()
# Out:
#              CEDULA    N° Cuentas       N° CDT  N° Tarjetas De Crédito  \
# count  4.950000e+02    496.000000   496.000000              496.000000
# mean   7.535331e+08    124.362903     6.060484               17.133065
# std    4.688963e+08   1382.455782    67.410490              190.452843
# min    5.824284e+06      0.000000     0.000000                0.000000
# 25%    6.681839e+07     43.000000     1.000000                5.000000
# 50%    1.022415e+09     60.000000     2.000000                9.000000
# 75%    1.075939e+09     77.000000     4.000000               12.000000
# max    1.233890e+09  30842.000000  1503.000000             4249.000000
#
#        N° Debitos Automáticos  Plan Familia (Millones)  Consumo (Millones)  \
# count              496.000000             4.960000e+02        4.960000e+02
# mean                 5.665323             9.618132e+06        1.307270e+08
# std                 63.024133             1.069391e+08        1.453730e+09
# ...

# %%
import pandas as pd
excel_1 = pd.read_excel("/content/sample_data/python1.xlsx")
excel_2 = pd.read_excel("/content/sample_data/python2.xlsx")
excel_3 = pd.read_excel("/content/sample_data/python3.xlsx")
excel_4 = pd.read_excel("/content/sample_data/python4.xlsx")
excel_5 = pd.read_excel("/content/sample_data/python5.xlsx")

# %%
excel_1
# Out:
#            CEDULA  N° Cuentas  N° CDT  N° Tarjetas De Crédito  \
# 0    9.375240e+06          64       2                      12
# 1    1.023008e+09          93       6                      16
# 2    4.196091e+07          61       3                      10
# 3    1.010229e+09          63       2                      14
# 4    1.054920e+09          80       3                      15
# ..            ...         ...     ...                     ...
# 491  8.080704e+07          85       9                      12
# 492  8.005812e+07          74       1                       8
# 493  5.206726e+07          78       6                      12
# 494  1.088009e+09          99       6                      19
# 495           NaN       30842    1503                    4249
#
#      N° Debitos Automáticos  Plan Familia (Millones)  Consumo (Millones)  \
# 0                         1             6.150000e+06        8.500000e+07
# ...

# %%
excel_2
# Out:
#          CEDULA  COD OFICINA   CODIGO GESTOR               OFICINA  \
# 0       9375240            12           9658      BOGOTÁ CHAPINERO
# 1    1023008416            73           9877       BOGOTÁ RESTREPO
# 2      41960913           228          31597        ARMENIA CENTRO
# 3    1010229345           280          36873   BOGOTÁ LOS HAYUELOS
# 4    1054920307           203           9817  PEREIRA DOSQUEBRADAS
# ..          ...           ...            ...                   ...
# 476  1019088583            51          38234       BOGOTÁ GALERIAS
# 477    80807040           634           9196  BOGOTÁ SUBA IMPERIAL
# 478    80058124           757           9863              MOSQUERA
# 479    52067261            37           9905      BOGOTÁ UNICENTRO
# 480  1088008856           206          37379  PEREIRA CRA. SEPTIMA
#
#                                 NOMBRE JORNADA  ZONA
# 0             LUIS JAVIER FUENTES LEON  NORMAL  9002
# 1         RUBEN DARIO JIMENEZ PRECIADO  NORMAL  9004
# ...

# %%
excel_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CEDULA         481 non-null    int64
#  1   COD OFICINA    481 non-null    int64
#  2   CODIGO GESTOR  481 non-null    int64
#  3   OFICINA        481 non-null    object
#  4   NOMBRE         481 non-null    object
#  5   JORNADA        481 non-null    object
#  6   ZONA           481 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 26.4+ KB

# %%
punto_1 = pd.merge(excel_2,excel_1, on='CEDULA', how='inner')

# %%
punto_1
# Out:
#          CEDULA  COD OFICINA   CODIGO GESTOR               OFICINA  \
# 0       9375240            12           9658      BOGOTÁ CHAPINERO
# 1    1023008416            73           9877       BOGOTÁ RESTREPO
# 2      41960913           228          31597        ARMENIA CENTRO
# 3    1010229345           280          36873   BOGOTÁ LOS HAYUELOS
# 4    1054920307           203           9817  PEREIRA DOSQUEBRADAS
# ..          ...           ...            ...                   ...
# 476  1019088583            51          38234       BOGOTÁ GALERIAS
# 477    80807040           634           9196  BOGOTÁ SUBA IMPERIAL
# 478    80058124           757           9863              MOSQUERA
# 479    52067261            37           9905      BOGOTÁ UNICENTRO
# 480  1088008856           206          37379  PEREIRA CRA. SEPTIMA
#
#                                 NOMBRE JORNADA  ZONA  N° Cuentas  N° CDT  \
# 0             LUIS JAVIER FUENTES LEON  NORMAL  9002          64       2
# ...

# %%
excel_3
# Out:
#                Nombre  Horas Extras  Valor a Pagar  Participación
# 0          Aura Mejia            52            NaN            NaN
# 1   Catalina Candamil            88            NaN            NaN
# 2     Diego Sarmiento            88            NaN            NaN
# 3     Hector Mosquera            56            NaN            NaN
# 4       Jalima Shaker            13            NaN            NaN
# 5        Javier Jerez            37            NaN            NaN
# 6         José Campos            25            NaN            NaN
# 7     Lianer Barragan            69            NaN            NaN
# 8     Marcela Caicedo            86            NaN            NaN
# 9       Myriam Farfan            63            NaN            NaN
# 10     Nayibe Peralta            22            NaN            NaN
# 11     Patricia López            17            NaN            NaN
# 12     Rafael Montoya            18            NaN            NaN
# ...

# %%
excel_3["Total a pagar"] =  excel_3["Horas Extras"]*5000

# %%
excel_3
# Out:
#                Nombre  Horas Extras  Valor a Pagar  Participación  \
# 0          Aura Mejia            52            NaN            NaN
# 1   Catalina Candamil            88            NaN            NaN
# 2     Diego Sarmiento            88            NaN            NaN
# 3     Hector Mosquera            56            NaN            NaN
# 4       Jalima Shaker            13            NaN            NaN
# 5        Javier Jerez            37            NaN            NaN
# 6         José Campos            25            NaN            NaN
# 7     Lianer Barragan            69            NaN            NaN
# 8     Marcela Caicedo            86            NaN            NaN
# 9       Myriam Farfan            63            NaN            NaN
# 10     Nayibe Peralta            22            NaN            NaN
# 11     Patricia López            17            NaN            NaN
# 12     Rafael Montoya            18            NaN            NaN
# ...

# %%
excel_4
# Out:
#       NOMBRE  EDAD ESTADO CIVIL  PRESTAMO
# 0     Marcos    35      SOLTERO       NaN
# 1     Felipe    40   DIVORCIADO       NaN
# 2     Sandra    28      SOLTERO       NaN
# 3    Marcela    36      SOLTERO       NaN
# 4      Ramón    23   DIVORCIADO       NaN
# 5       Juan    51      SOLTERO       NaN
# 6    Enrique    34      SOLTERO       NaN
# 7   Fernando    48   DIVORCIADO       NaN
# 8    Natalia    26      SOLTERO       NaN
# 9     Ximena    22   DIVORCIADO       NaN
# 10  Carolina    36      SOLTERO       NaN

# %%
excel_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NOMBRE        11 non-null     object
#  1   EDAD          11 non-null     int64
#  2   ESTADO CIVIL  11 non-null     object
#  3   PRESTAMO      0 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 480.0+ bytes

# %%
import numpy as np

# %%
excel_4["RESULTADO"] = np.where((excel_4["EDAD"]>=29) & (excel_4["ESTADO CIVIL"]=="SOLTERO"),"APROBADO","NEGADO")

# %%
excel_4
# Out:
#       NOMBRE  EDAD ESTADO CIVIL  PRESTAMO RESULTADO
# 0     Marcos    35      SOLTERO       NaN  APROBADO
# 1     Felipe    40   DIVORCIADO       NaN    NEGADO
# 2     Sandra    28      SOLTERO       NaN    NEGADO
# 3    Marcela    36      SOLTERO       NaN  APROBADO
# 4      Ramón    23   DIVORCIADO       NaN    NEGADO
# 5       Juan    51      SOLTERO       NaN  APROBADO
# 6    Enrique    34      SOLTERO       NaN  APROBADO
# 7   Fernando    48   DIVORCIADO       NaN    NEGADO
# 8    Natalia    26      SOLTERO       NaN    NEGADO
# 9     Ximena    22   DIVORCIADO       NaN    NEGADO
# 10  Carolina    36      SOLTERO       NaN  APROBADO

# %%
excel_5
# Out:
#        NOMBRE  SALARIO  AÑOS DE SERVICIO
# 0   Alexander  3500000                10
# 1      Martha   950000                 1
# 2        Raúl  1500000                20
# 3       David  2800000                 5
# 4       Diego   750000                10
# 5        Juan  1500000                 1
# 6      Angela  2800000                11
# 7        Dora  1650000                12
# 8     Absalon   200000                 5
# 9     Adriana  2500000                 4
# 10      Rocio  1400000                10

# %%
excel_5["RESULTADO"] = np.where((excel_5["SALARIO"]<1000000) | (excel_5["AÑOS DE SERVICIO"]>10),"TIENE BONIFICACION","NO TIENE BONIFICACION")

# %%
excel_5
# Out:
#        NOMBRE  SALARIO  AÑOS DE SERVICIO              RESULTADO
# 0   Alexander  3500000                10  NO TIENE BONIFICACION
# 1      Martha   950000                 1     TIENE BONIFICACION
# 2        Raúl  1500000                20     TIENE BONIFICACION
# 3       David  2800000                 5  NO TIENE BONIFICACION
# 4       Diego   750000                10     TIENE BONIFICACION
# 5        Juan  1500000                 1  NO TIENE BONIFICACION
# 6      Angela  2800000                11     TIENE BONIFICACION
# 7        Dora  1650000                12     TIENE BONIFICACION
# 8     Absalon   200000                 5     TIENE BONIFICACION
# 9     Adriana  2500000                 4  NO TIENE BONIFICACION
# 10      Rocio  1400000                10  NO TIENE BONIFICACION
